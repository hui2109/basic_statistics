# %%
# %matplotlib inline
# https://zhuanlan.zhihu.com/p/93423829
import matplotlib.pyplot as plt
import numpy as np

# %%
A = np.arange(1, 5)
B = A ** 2
C = A ** 3

# %%
figure, ax = plt.subplots(figsize=(14, 7))

# %%
ax.plot(A, B)
ax.plot(B, A)
figure
# Out:
# /Users/kukudehui/Documents/01_编程学习/python/11_基础统计/venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ax.set_title('Title', fontsize=18)
ax.set_xlabel('xlabel', fontsize=18, fontfamily='Times New Roman', fontstyle='italic')
ax.set_ylabel('ylabel', fontsize='x-large', fontstyle='oblique')
# ax.legend()
# Out:
# Text(28.546874999999872, 0.5, 'ylabel')

# %%
ax.set_aspect('equal')
ax.minorticks_on()
ax.set_xlim(0, 16)
ax.grid(which='minor', axis='both')

# %%
ax.xaxis.set_tick_params(rotation=45, labelsize=18, colors='g')
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, 1))
ax.yaxis.tick_right()

# %%
figure
